# %% [markdown]
# # Atividade
# ## Panorama das Tecnologias
#
# ## Tarefa
#
# Pesquisar e associar os propósitos (papeis) aos produtos e ferramentas.
#
# OBS: Um propósito pode ter mais de uma ferramenta e uma ferramenta mais de um propósito
#
# **Em grupo**

# %% [markdown]
# # Propósito, Papel ou Problema
#
# 1. Motor de Regras
#
#
# 2. Camada de Ingestão
#
#
# 3. Ferramenta de Coordenação
#
#
# 4. Bancos de Dados NoSQL
#
#
# 5. Armazenamento Hadoop
#
#
# 6. Ferramentas de Analytics
#
#
# 7. Monitoramento
#
#
# 8. Data Warehouse NoSQL
#
#
# 9. Mecanismo de Busca (Search)
#
#
# 10. Infraestrutura Virtual Pública Baseada em Nuvem
#
#
# 11. Soluções de Analytics de Big Data
#
#
# 12. Administração Hadoop
#
#
# 13. Ferramentas de Busca (Query)
#
#
# 14. IDE de Analistas de Dados
#
#
# 15. Ferramentas de Visualização

# %% [markdown]
# # Ferramentas e Soluções
#
# 1. Cloudera
#
#
# 2. Solr
#
#
# 3. Tableau
#
#
# 4. Tarefas MapReduce
#
#
# 5. Apache Storm
#
#
# 6. Hortonworks
#
#
# 7. MapReduce
#
#
# 8. IBM Pure Systems
#
#
# 9. Pentaho
#
#
# 10. IBM Big Insights
#
#
# 11. Oracle Exalytics
#
#
# 12. IBM Netezza
#
#
# 13. DataStax
#
#
# 14. Pig
#
#
# 15. Rackspace
#
#
# 16. HDFS
#
#
# 17. Talend
#
#
# 18. EMC Greenplum
#
#
# 19. ZooKeeper, Oozie
#
#
# 20. Clickview
#
#
# 21. Nagios
#
#
# 22. Amazon S3
#
#
# 23. Yarn
#
#
# 24. Amazon AWS
#
#
# 25. R
#
#
# 26. HBase, Cassandra
#
#
# 27. Ganglia
#
#
# 28. Spotfire
#
#
# 29. Hive
#
#
# 30. Apache Flume
